# %% [markdown]
# <a href="https://colab.research.google.com/github/yusukebb/collective/blob/main/heavy_2D_15_20230120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
import gc

from tqdm import tqdm
import pickle

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras.layers.core import *
from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

# instead of utils
#from utils import *
import pandas as pd
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 15 # the number of joints
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 21 # the number of class
        self.feat_d = 105
        self.filters = 64
        self.data_dir = '/content/drive/MyDrive/collective/DD_test/data'
C = Config()

# %%
# Temple resizing function
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim]) 
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]         
    return p_new



# Calculate JCD feature
def norm_scale(x):
    return (x-np.mean(x))/np.mean(x)
  
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l): 
        d_m = cdist(p[f],p[f],'euclidean')       
        d_m = d_m[iu] 
        M.append(d_m)
    M = np.stack(M) 
    M = norm_scale(M)
    return M
  
  
# Genrate dataset  
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))): 
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1   

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)  
    X_1 = np.stack(X_1) 
    Y = np.stack(Y)
    return X_0,X_1,Y

# %%
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))): 
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1   

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)  
    X_1 = np.stack(X_1) 
    Y = np.stack(Y)
    return X_0,X_1,Y

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast
    
def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x
    
def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):   
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    
    diff_slow,diff_fast = pose_motion(P,frame_l)
    
    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
        
    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
   
    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)
    
    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)
    
    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))  
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d)) 
    
    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)
    
    x = FM([M,P])

    x = GlobalMaxPool1D()(x)
    
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)
        
    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  M (InputLayer)                 [(None, 32, 105)]    0           []
#
#  P (InputLayer)                 [(None, 32, 15, 2)]  0           []
#
#  model (Functional)             (None, 4, 512)       1714816     ['M[0][0]',
#                                                                   'P[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 512)         0           ['model[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 128)          65536       ['global_max_pooling1d[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 128)         512         ['dense[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 128)          0           ['batch_normalization_15[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['leaky_re_lu_15[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16384       ['dropout[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 128)         512         ['dense_1[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 128)          0           ['batch_normalization_16[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['leaky_re_lu_16[0][0]']
#
#  dense_2 (Dense)                (None, 21)           2709        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,800,469
# Trainable params: 1,794,837
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %%
# Train = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/JHMDB/GT_train_1.pkl", "rb"))
#Train = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/our_train.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/our_test.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/sit.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/jump.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/sitandjump.pkl", "rb"))
# Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/sitandjump_10000.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/modofi.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/JHMDB/GT_test_1.pkl", "rb"))
Train = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/ours/train_2D_15.pkl", "rb"))
Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/ours/test_2D_15.pkl", "rb"))
#Train = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/ours/train_2D_34.pkl", "rb"))
#Test = pickle.load(open("/content/drive/MyDrive/collective/DD_test/data/ours/test_2D_34.pkl", "rb"))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0,X_1,Y = data_generator(Train,C,le)
X_test_0,X_test_1,Y_test = data_generator(Test,C,le)
# Out:
# 100%|██████████| 235/235 [00:03<00:00, 74.13it/s]
# 100%|██████████| 108/108 [00:01<00:00, 76.15it/s]

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=300,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)      
                    )
"""lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=70,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)      
                    )"""
# Out:
# Epoch 1/300
# 1/1 [==============================] - 18s 18s/step - loss: 3.6892 - accuracy: 0.0213 - val_loss: 4.2333 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/300
# 1/1 [==============================] - 2s 2s/step - loss: 3.2668 - accuracy: 0.0723 - val_loss: 3.6678 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/300
# 1/1 [==============================] - 2s 2s/step - loss: 2.9295 - accuracy: 0.1489 - val_loss: 3.7733 - val_accuracy: 0.0093 - lr: 0.0010
# Epoch 4/300
# 1/1 [==============================] - 2s 2s/step - loss: 2.6905 - accuracy: 0.2596 - val_loss: 3.6917 - val_accuracy: 0.1574 - lr: 0.0010
# Epoch 5/300
# 1/1 [==============================] - 2s 2s/step - loss: 2.5023 - accuracy: 0.3787 - val_loss: 2.9408 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 6/300
# 1/1 [==============================] - 2s 2s/step - loss: 2.2407 - accuracy: 0.5149 - val_loss: 2.9131 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 7/300
# 1/1 [==============================] - 2s 2s/step - loss: 2.0463 - accuracy: 0.5957 - val_loss: 2.8810 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 8/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.6797 - accuracy: 0.7532 - val_loss: 2.8503 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 9/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.4051 - accuracy: 0.7660 - val_loss: 2.8207 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 10/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.3987 - accuracy: 0.7872 - val_loss: 2.7935 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 11/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.2306 - accuracy: 0.8255 - val_loss: 2.7653 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 12/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.0176 - accuracy: 0.8511 - val_loss: 2.7319 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 13/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.8219 - accuracy: 0.8851 - val_loss: 2.7062 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 14/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.8311 - accuracy: 0.9021 - val_loss: 2.6893 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 15/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.8034 - accuracy: 0.8979 - val_loss: 2.6827 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 16/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.6556 - accuracy: 0.9234 - val_loss: 2.6866 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 17/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.5487 - accuracy: 0.9404 - val_loss: 2.7131 - val_accuracy: 0.2407 - lr: 0.0010
# Epoch 18/300
# 1/1 [==============================] - 2s 2s/step - loss: 0
300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.3792 - val_accuracy: 0.8889 - lr: 5.0000e-06
# Epoch 190/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.3645 - val_accuracy: 0.8981 - lr: 5.0000e-06
# Epoch 191/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.8981 - lr: 5.0000e-06
# Epoch 192/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.8981 - lr: 5.0000e-06
# Epoch 193/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.3258 - val_accuracy: 0.9167 - lr: 5.0000e-06
# Epoch 194/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0294 - accuracy: 0.9957 - val_loss: 0.3136 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 195/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 196/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0250 - accuracy: 0.9957 - val_loss: 0.2909 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 197/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 198/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 199/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 200/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.2484 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 201/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 202/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9259 - lr: 5.0000e-06
# Epoch 203/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9352 - lr: 5.0000e-06
# Epoch 204/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9352 - lr: 5.0000e-06
# Epoch 205/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2013 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 206/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 207/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 208/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 209/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 210/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 211/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 212/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 213/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9444 - lr: 5.0000e-06
# Epoch 214/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9630 - lr: 5.0000e-06
# Epoch 215/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9630 - lr: 5.0000e-06
# Epoch 216/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 217/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 218/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 219/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0246 - accuracy: 0.9957 - val_loss: 0.1085 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 220/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 221/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 222/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 223/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 224/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 225/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0893 - val_accuracy: 0.9815 - lr: 5.0000e-06
# Epoch 226/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 227/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 228/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 229/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0202 - accuracy: 0.9957 - val_loss: 0.0811 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 230/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 231/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 232/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 233/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 234/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 235/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 236/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 237/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 238/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 239/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 240/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 241/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 242/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 243/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 244/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 245/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 246/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 247/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 248/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 249/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 250/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0214 - accuracy: 0.9957 - val_loss: 0.0657 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 251/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 252/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 253/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0232 - accuracy: 0.9957 - val_loss: 0.0647 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 254/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 255/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 256/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 257/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 258/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 259/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 260/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 261/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 262/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.0622 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 263/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 264/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 265/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 266/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 267/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 268/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 269/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 270/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 271/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 272/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 273/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 274/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 275/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 276/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 277/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 278/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0268 - accuracy: 0.9957 - val_loss: 0.0590 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 279/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 280/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 281/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 282/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0584 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 283/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 284/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 285/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0578 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 286/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 287/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 288/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 289/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 290/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0202 - accuracy: 0.9957 - val_loss: 0.0570 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 291/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 292/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 293/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0565 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 294/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 295/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 296/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0321 - accuracy: 0.9957 - val_loss: 0.0559 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 297/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 298/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0556 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 299/300
# 1/1 [==============================] - 2s 2s/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 0.9907 - lr: 5.0000e-06
# Epoch 300/300
# 1/1 [==============================] - 1s 1s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9907 - lr: 5.0000e-06
# 'lr = 1e-4\nDD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=[\'accuracy\'])\nlrScheduler = keras.callbacks.ReduceLROnPlateau(monitor=\'loss\', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)\nhistory = DD_Net.fit([X_0,X_1],Y,\n                    batch_size=len(Y),\n                    epochs=70,\n                    verbose=True,\n                    shuffle=True,\n                    callbacks=[lrScheduler],\n                    validation_data=([X_test_0,X_test_1],Y_test)      \n                    )'

# %%
# lr = 1e-4
# DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
# lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
# history = DD_Net.fit([X_0,X_1],Y,
#                     batch_size=len(Y),
#                     epochs=300,
#                     verbose=True,
#                     shuffle=True,
#                     callbacks=[lrScheduler],
#                     validation_data=([X_test_0,X_test_1],Y_test)
# )

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
